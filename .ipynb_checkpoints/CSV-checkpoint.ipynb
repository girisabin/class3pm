# %%
#  CSV-comma separated value

# %%
file = open("data.csv",'x')
file.close()

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df
# Out:
#    Sn    Name  Age    Address         Phone
# 0   1     Ram   33  Kathmandu    9803245643
# 1   2   Shyam   43       Bara   98033232323
# 2   3    Hari   45    Pokhara   98034344433
# 3   4   Kiran   23    Lamjung  983434434433
# 4   5  Karina   24  Bhaktapur    9833434344
# 5   6    Gita   34   Lalitpur   98434344344

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows= 5)
df
# Out:
#    Sn    Name  Age    Address         Phone
# 0   1     Ram   33  Kathmandu    9803245643
# 1   2   Shyam   43       Bara   98033232323
# 2   3    Hari   45    Pokhara   98034344433
# 3   4   Kiran   23    Lamjung  983434434433
# 4   5  Karina   24  Bhaktapur    9833434344

# %%
import pandas as pd
df = pd.read_csv('data.csv',nrows= 5,index_col = 'Sn')
df
# Out:
#       Name  Age    Address         Phone
# Sn
# 1      Ram   33  Kathmandu    9803245643
# 2    Shyam   43       Bara   98033232323
# 3     Hari   45    Pokhara   98034344433
# 4    Kiran   23    Lamjung  983434434433
# 5   Karina   24  Bhaktapur    9833434344

# %%
df['Name']
# Out:
# Sn
# 1       Ram
# 2     Shyam
# 3      Hari
# 4     Kiran
# 5    Karina
# Name: Name, dtype: object

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.head(4)
# Out:
#      Name  Age    Address         Phone
# Sn
# 1     Ram   33  Kathmandu    9803245643
# 2   Shyam   43       Bara   98033232323
# 3    Hari   45    Pokhara   98034344433
# 4   Kiran   23    Lamjung  983434434433

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.tail(3)
# Out:
#       Name  Age    Address         Phone
# Sn
# 4    Kiran   23    Lamjung  983434434433
# 5   Karina   24  Bhaktapur    9833434344
# 6     Gita   34   Lalitpur   98434344344

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn',usecols = ['Sn','Name','Phone'])
df
# Out:
#       Name         Phone
# Sn
# 1      Ram    9803245643
# 2    Shyam   98033232323
# 3     Hari   98034344433
# 4    Kiran  983434434433
# 5   Karina    9833434344
# 6     Gita   98434344344

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df['Address']
# Out:
# Sn
# 1    Kathmandu
# 2         Bara
# 3      Pokhara
# 4      Lamjung
# 5    Bhaktapur
# 6     Lalitpur
# Name: Address, dtype: object

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df[df['Address'] == 'Kathmandu']
# Out:
#    Name  Age    Address       Phone
# Sn
# 1   Ram   33  Kathmandu  9803245643

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
data = df[df['Address'] == 'Kathmandu']
data.to_csv('new_data.csv')

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
data = df[df['Age'] >30]
data
# Out:
#      Name  Age    Address        Phone
# Sn
# 1     Ram   33  Kathmandu   9803245643
# 2   Shyam   43       Bara  98033232323
# 3    Hari   45    Pokhara  98034344433
# 6    Gita   34   Lalitpur  98434344344

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Sn')
df.iloc[1:4,0:3]  #[row-range,column-range]
# Out:
#      Name  Age  Address
# Sn
# 2   Shyam   43     Bara
# 3    Hari   45  Pokhara
# 4   Kiran   23  Lamjung

# %%
import pandas as pd
df = pd.read_csv('data.csv',index_col = 'Name')
df.loc['Ram':'Gita']  #only row range
# Out:
#         Sn  Age    Address         Phone
# Name
# Ram      1   33  Kathmandu    9803245643
# Shyam    2   43       Bara   98033232323
# Hari     3   45    Pokhara   98034344433
# Kiran    4   23    Lamjung  983434434433
# Karina   5   24  Bhaktapur    9833434344
# Gita     6   34   Lalitpur   98434344344

# %%
import pandas as pd
data = {'Ram':[980232323,443434], 'Shyam':[983434343,4545454]}
df = pd.DataFrame(data)
df.to_csv('phone_no.csv')
df
# Out:
#          Ram      Shyam
# 0  980232323  983434343
# 1     443434    4545454
